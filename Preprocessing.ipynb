# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
crime_data = pd.read_csv("/Users/HOME/Desktop/LosAngelesCrime/data/datawrangling.csv",index_col = 0)
crime_data.head()
# Out:
#        dr_no   date_rptd    date_occ time_occ  area  area_name  rpt_dist_no  \
# 0    1307355  2010-02-20  2010-02-20    13:50    13     Newton         1385
# 1   11401303  2010-09-13  2010-09-12    00:45    14    Pacific         1485
# 2   70309629  2010-08-09  2010-08-09    15:15    13     Newton         1324
# 3   90631215  2010-01-05  2010-01-05    01:50     6  Hollywood          646
# 4  100100501  2010-01-03  2010-01-02    21:00     1    Central          176
#
#    crm_cd                                        crm_cd_desc         mocodes  \
# 0     900                           VIOLATION OF COURT ORDER  0913 1814 2000
# 1     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            0329
# 2     946                          OTHER MISCELLANEOUS CRIME            0344
# 3     900                           VIOLATION OF COURT ORDER  1100 0400 1402
# 4     122                                    RAPE, ATTEMPTED            0400
#
#    ...             premis_desc weapon_used_cd  \
# 0  ...  SINGLE FAMILY DWELLING          500.0
# 1  ...                  STREET          500.0
# 2  ...                   ALLEY          500.0
# 3  ...                  STREET          102.0
# 4  ...                   ALLEY          400.0
#
#                                       weapon_desc  status   status_desc  \
# 0                     UNKNOWN WEAPON/OTHER WEAPON      AA  Adult Arrest
# 1                     UNKNOWN WEAPON/OTHER WEAPON      IC   Invest Cont
# 2                     UNKNOWN WEAPON/OTHER WEAPON      IC   Invest Cont
# 3                                        HAND GUN      IC   Invest Cont
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      IC   Invest Cont
#
#                                   location      lat       lon day_crime_occ  \
# 0   300 E  GAGE                         AV  33.9825 -118.2695      Saturday
# 1          SEPULVEDA                    BL  33.9599 -118.3962        Sunday
# 2  1300 E  21ST                         ST  34.0224 -118.2524        Monday
# 3          CAHUENGA                     BL  34.1016 -118.3295       Tuesday
# 4          8TH                          ST  34.0387 -118.2488      Saturday
#
#                  no_rptd_occ
# 0  0 days 00:00:00.000000000
# 1  1 days 00:00:00.000000000
# 2  0 days 00:00:00.000000000
# 3  0 days 00:00:00.000000000
# 4  1 days 00:00:00.000000000
#
# [5 rows x 24 columns]

# %%
df = crime_data.copy()

# %%
df['Hour'] = pd.to_numeric(df['time_occ'].apply(lambda x : x[:2]))

# %%
df['Minutes'] = pd.to_numeric(df['time_occ'].apply(lambda x : x[-2:]))

# %%
df['no_rptd_occ'] = pd.to_numeric(df['no_rptd_occ'].apply(lambda x: x.split(" ")[0]))

# %%
df['day_crime_occ'] = pd.to_datetime(crime_data['date_occ']).dt.weekday

# %%
df['month_crime_occ']= pd.to_datetime(crime_data['date_occ']).dt.month

# %%
df['year_crime_occ'] = pd.to_datetime(crime_data['date_occ']).dt.year

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['date_rptd', 'date_occ', 'time_occ', 'area_name', 'crm_cd_desc',
#        'mocodes', 'vict_sex', 'vict_descent', 'premis_desc', 'weapon_desc',
#        'status', 'status_desc', 'location'],
#       dtype='object')

# %%
len(df.location.unique())
# Out:
# 75303

# %%
df.drop(['date_rptd','date_occ','time_occ','mocodes','rpt_dist_no'],axis =1,inplace = True)

# %%
df.to_csv('/Users/HOME/Desktop/LosAngelesCrime/data/step3_output.csv')

# %%
df.columns
# Out:
# Index(['dr_no', 'area', 'area_name', 'crm_cd', 'crm_cd_desc', 'vict_age',
#        'vict_sex', 'vict_descent', 'premis_cd', 'premis_desc',
#        'weapon_used_cd', 'weapon_desc', 'status', 'status_desc', 'location',
#        'lat', 'lon', 'day_crime_occ', 'no_rptd_occ', 'Hour', 'Minutes',
#        'month_crime_occ', 'year_crime_occ'],
#       dtype='object')

# %%
df.drop(['crm_cd','premis_cd','weapon_used_cd','status'],axis=1,inplace = True)

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['area_name', 'crm_cd_desc', 'vict_sex', 'vict_descent', 'premis_desc',
#        'weapon_desc', 'status_desc', 'location'],
#       dtype='object')

# %% [markdown]
# #### print the categorical columns and their associated levels

# %%
dfo = df.select_dtypes(include=['object'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#         VarName  LevelsCount
# 0     area_name           21
# 1   crm_cd_desc          142
# 2      vict_sex            3
# 3  vict_descent           19
# 4   premis_desc          319
# 5   weapon_desc           79
# 6        status            6
# 7   status_desc            6
# 8      location        75303

# %% [markdown]
# ### Stratified Sampling

# %%
def stratified_sample(df, strata, size=None, seed=None, keep_index= True):
    
    population = len(df)
    size = __smpl_size(population, size)
    tmp = df[strata]
    tmp['size'] = 1
    tmp_grpd = tmp.groupby(strata).count().reset_index()
    tmp_grpd['samp_size'] = round(size/population * tmp_grpd['size']).astype(int)

    # controlling variable to create the dataframe or append to it
    first = True 
    for i in range(len(tmp_grpd)):
        # query generator for each iteration
        qry=''
        for s in range(len(strata)):
            stratum = strata[s]
            value = tmp_grpd.iloc[i][stratum]
            n = tmp_grpd.iloc[i]['samp_size']

            if type(value) == str:
                value = "'" + str(value) + "'"
            
            if s != len(strata)-1:
                qry = qry + stratum + ' == ' + str(value) +' & '
            else:
                qry = qry + stratum + ' == ' + str(value)
        
        # final dataframe
        if first:
            stratified_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            first = False
        else:
            tmp_df = df.query(qry).sample(n=n, random_state=seed).reset_index(drop=(not keep_index))
            stratified_df = stratified_df.append(tmp_df, ignore_index=True)
    
    return stratified_df



def stratified_sample_report(df, strata, size=None):
    
    population = len(df)
    size = __smpl_size(population, size)
    tmp = df[strata]
    tmp['size'] = 1
    tmp_grpd = tmp.groupby(strata).count().reset_index()
    tmp_grpd['samp_size'] = round(size/population * tmp_grpd['size']).astype(int)
    return tmp_grpd


def __smpl_size(population, size):
    
    if size is None:
        cochran_n = round(((1.96)**2 * 0.5 * 0.5)/ 0.02**2)
        n = round(cochran_n/(1+((cochran_n -1) /population)))
    elif size >= 0 and size < 1:
        n = round(population * size)
    elif size < 0:
        raise ValueError('Parameter "size" must be an integer or a proportion between 0 and 0.99.')
    elif size >= 1:
        n = size
    return n

# %% [markdown]
# #### Subsampling(20000 observations) the dataset because of its large size(2000000) using stratified sampling

# %%
sample_df = stratified_sample(df, ['crm_cd_desc','area_name'], size=20000, seed=123, keep_index= True)
sample_df.head()
# Out:
#      index      dr_no  area    area_name  crm_cd crm_cd_desc  vict_age  \
# 0  1110886  151200099    12  77th Street     648       ARSON        48
# 1   349876  111212546    12  77th Street     648       ARSON        35
# 2   104180  101217118    12  77th Street     648       ARSON        37
# 3  2052286  190109104     1      Central     648       ARSON         0
# 4  1594714  170105069     1      Central     648       ARSON        16
#
#   vict_sex            vict_descent  premis_cd  ...  status_desc  \
# 0        M                   Black      501.0  ...  Invest Cont
# 1        M  Hispanic/Latin/Mexican      502.0  ...  Invest Cont
# 2        F  Hispanic/Latin/Mexican      501.0  ...  Invest Cont
# 3        M                   Other      502.0  ...  Invest Cont
# 4        M                   Other      753.0  ...  Invest Cont
#
#                                    location      lat       lon day_crime_occ  \
# 0    900 W  69TH                         ST  33.9773 -118.2892             4
# 1   7900 S  HOOVER                       ST  33.9678 -118.2871             6
# 2    800 E  82ND                         ST  33.9647 -118.2608             1
# 3                                      HOPE  34.0423 -118.2631             4
# 4  00100 N  LOS ANGELES                  ST  34.0515 -118.2424             3
#
#   no_rptd_occ  Hour  Minutes  month_crime_occ  year_crime_occ
# 0           1     1       17                2            2015
# 1           0     6        0                5            2011
# 2           3    23        0                6            2010
# 3           0     6       30                3            2019
# 4           0     9       30                1            2017
#
# [5 rows x 24 columns]

# %%
sample_dfo = sample_df.select_dtypes(include=['object'])
sample_dfo.shape
#get levels for all variables
vn = pd.DataFrame(sample_dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#         VarName  LevelsCount
# 0     area_name           21
# 1   crm_cd_desc           93
# 2      vict_sex            3
# 3  vict_descent           15
# 4   premis_desc          200
# 5   weapon_desc           63
# 6        status            6
# 7   status_desc            6
# 8      location        12522

# %%
from collections import Counter 
# summarize the class distribution
target = sample_df['crm_cd_desc'].values
counter = Counter(target)
for k,v in counter.items():
    per = v / len(target) * 100
    print('Class=%s, Count=%d, Percentage  =  %.5f%%' % (k, v, per))
# Out:
# Class=ARSON, Count=33, Percentage  =  0.16568%
# Class=ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER, Count=13, Percentage  =  0.06527%
# Class=ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT, Count=878, Percentage  =  4.40807%
# Class=ATTEMPTED ROBBERY, Count=113, Percentage  =  0.56733%
# Class=BATTERY - SIMPLE ASSAULT, Count=1802, Percentage  =  9.04709%
# Class=BATTERY POLICE (SIMPLE), Count=46, Percentage  =  0.23095%
# Class=BATTERY WITH SEXUAL CONTACT, Count=108, Percentage  =  0.54222%
# Class=BIKE - STOLEN, Count=137, Percentage  =  0.68782%
# Class=BOMB SCARE, Count=9, Percentage  =  0.04519%
# Class=BRANDISH WEAPON, Count=144, Percentage  =  0.72296%
# Class=BUNCO, ATTEMPT, Count=3, Percentage  =  0.01506%
# Class=BUNCO, GRAND THEFT, Count=85, Percentage  =  0.42675%
# Class=BUNCO, PETTY THEFT, Count=51, Percentage  =  0.25605%
# Class=BURGLARY, Count=1396, Percentage  =  7.00874%
# Class=BURGLARY FROM VEHICLE, Count=1535, Percentage  =  7.70660%
# Class=BURGLARY FROM VEHICLE, ATTEMPTED, Count=24, Percentage  =  0.12049%
# Class=BURGLARY, ATTEMPTED, Count=117, Percentage  =  0.58741%
# Class=CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT, Count=14, Percentage  =  0.07029%
# Class=CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT, Count=88, Percentage  =  0.44181%
# Class=CHILD ANNOYING (17YRS & UNDER), Count=49, Percentage  =  0.24601%
# Class=CHILD NEGLECT (SEE 300 W.I.C.), Count=51, Percentage  =  0.25605%
# Class=CHILD STEALING, Count=9, Percentage  =  0.04519%
# Class=CONTEMPT OF COURT, Count=36, Percentage  =  0.18074%
# Class=COUNTERFEIT, Count=3, Percentage  =  0.01506%
# Class=CREDIT CARDS, FRAUD USE ($950 & UNDER, Count=1, Percentage  =  0.00502%
# Class=CREDIT CARDS, FRAUD USE ($950.01 & OVER), Count=4, Percentage  =  0.02008%
# Class=CRIMINAL HOMICIDE, Count=27, Percentage  =  0.13556%
# Class=CRIMINAL THREATS - NO WEAPON DISPLAYED, Count=536, Percentage  =  2.69103%
# Class=CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER), Count=82, Percentage  =  0.41169%
# Class=CRUELTY TO ANIMALS, Count=15, Percentage  =  0.07531%
# Class=DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER, Count=20, Percentage  =  0.10041%
# Class=DISCHARGE FIREARMS/SHOTS FIRED, Count=34, Percentage  =  0.17070%
# Class=DISTURBING THE PEACE, Count=35, Percentage  =  0.17572%
# Class=DOCUMENT FORGERY / STOLEN FELONY, Count=215, Percentage  =  1.07943%
# Class=DOCUMENT WORTHLESS ($200.01 & OVER), Count=1, Percentage  =  0.00502%
# Class=DRIVING WITHOUT OWNER CONSENT (DWOC), Count=1, Percentage  =  0.00502%
# Class=EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER), Count=76, Percentage  =  0.38156%
# Class=EMBEZZLEMENT, PETTY THEFT ($950 & UNDER), Count=3, Percentage  =  0.01506%
# Class=EXTORTION, Count=23, Percentage  =  0.11547%
# Class=FAILURE TO YIELD, Count=2, Percentage  =  0.01004%
# Class=FALSE IMPRISONMENT, Count=8, Percentage  =  0.04016%
# Class=FALSE POLICE REPORT, Count=1, Percentage  =  0.00502%
# Class=HUMAN TRAFFICKING - COMMERCIAL SEX ACTS, Count=3, Percentage  =  0.01506%
# Class=ILLEGAL DUMPING, Count=1, Percentage  =  0.00502%
# Class=INDECENT EXPOSURE, Count=35, Percentage  =  0.17572%
# Class=INTIMATE PARTNER - AGGRAVATED ASSAULT, Count=146, Percentage  =  0.73301%
# Class=INTIMATE PARTNER - SIMPLE ASSAULT, Count=1086, Percentage  =  5.45235%
# Class=KIDNAPPING, Count=20, Percentage  =  0.10041%
# Class=KIDNAPPING - GRAND ATTEMPT, Count=3, Percentage  =  0.01506%
# Class=LETTERS, LEWD  -  TELEPHONE CALLS, LEWD, Count=198, Percentage  =  0.99408%
# Class=LEWD CONDUCT, Count=15, Percentage  =  0.07531%
# Class=LEWD/LASCIVIOUS ACTS WITH CHILD, Count=1, Percentage  =  0.00502%
# Class=ORAL COPULATION, Count=22, Percentage  =  0.11045%
# Class=OTHER ASSAULT, Count=41, Percentage  =  0.20584%
# Class=OTHER MISCELLANEOUS CRIME, Count=195, Percentage  =  0.97901%
# Class=PANDERING, Count=2, Percentage  =  0.01004%
# Class=PEEPING TOM, Count=10, Percentage  =  0.05021%
# Class=PICKPOCKET, Count=8, Percentage  =  0.04016%
# Class=PIMPING, Count=3, Percentage  =  0.01506%
# Class=PROWLER, Count=4, Percentage  =  0.02008%
# Class=PURSE SNATCHING, Count=9, Percentage  =  0.04519%
# Class=RAPE, ATTEMPTED, Count=9, Percentage  =  0.04519%
# Class=RAPE, FORCIBLE, Count=99, Percentage  =  0.49704%
# Class=RESISTING ARREST, Count=31, Percentage  =  0.15564%
# Class=ROBBERY, Count=794, Percentage  =  3.98634%
# Class=SEX OFFENDER REGISTRANT OUT OF COMPLIANCE, Count=15, Percentage  =  0.07531%
# Class=SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ, Count=41, Percentage  =  0.20584%
# Class=SEXUAL PENETRATION W/FOREIGN OBJECT, Count=24, Percentage  =  0.12049%
# Class=SHOPLIFTING - PETTY THEFT ($950 & UNDER), Count=457, Percentage  =  2.29441%
# Class=SHOPLIFTING-GRAND THEFT ($950.01 & OVER), Count=45, Percentage  =  0.22593%
# Class=SHOTS FIRED AT INHABITED DWELLING, Count=22, Percentage  =  0.11045%
# Class=SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT, Count=1, Percentage  =  0.00502%
# Class=SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH, Count=16, Percentage  =  0.08033%
# Class=STALKING, Count=21, Percentage  =  0.10543%
# Class=THEFT FROM MOTOR VEHICLE - ATTEMPT, Count=14, Percentage  =  0.07029%
# Class=THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER), Count=299, Percentage  =  1.50115%
# Class=THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER), Count=834, Percentage  =  4.18717%
# Class=THEFT OF IDENTITY, Count=1201, Percentage  =  6.02972%
# Class=THEFT PLAIN - ATTEMPT, Count=19, Percentage  =  0.09539%
# Class=THEFT PLAIN - PETTY ($950 & UNDER), Count=1417, Percentage  =  7.11417%
# Class=THEFT, PERSON, Count=141, Percentage  =  0.70790%
# Class=THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD, Count=702, Percentage  =  3.52445%
# Class=THREATENING PHONE CALLS/LETTERS, Count=31, Percentage  =  0.15564%
# Class=THROWING OBJECT AT MOVING VEHICLE, Count=20, Percentage  =  0.10041%
# Class=TRESPASSING, Count=205, Percentage  =  1.02922%
# Class=UNAUTHORIZED COMPUTER ACCESS, Count=12, Percentage  =  0.06025%
# Class=VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS), Count=1034, Percentage  =  5.19128%
# Class=VANDALISM - MISDEAMEANOR ($399 OR UNDER), Count=855, Percentage  =  4.29260%
# Class=VEHICLE - ATTEMPT STOLEN, Count=30, Percentage  =  0.15062%
# Class=VEHICLE - STOLEN, Count=1515, Percentage  =  7.60619%
# Class=VIOLATION OF COURT ORDER, Count=190, Percentage  =  0.95391%
# Class=VIOLATION OF RESTRAINING ORDER, Count=182, Percentage  =  0.91375%
# Class=VIOLATION OF TEMPORARY RESTRAINING ORDER, Count=12, Percentage  =  0.06025%

# %% [markdown]
# ### Handling Rare categories

# %% [markdown]
# ##### Categories that are occures less than 6 times of the total observations are moved to OTHER CRIME category

# %%
value_counts = sample_df['crm_cd_desc'].value_counts() # Specific column 
to_remove = value_counts[value_counts <= 6].index
sample_df['crm_cd_desc'].replace(to_remove, 'OTHER MISCELLANEOUS CRIME', inplace=True)

# %%
sample_dfo = sample_df.select_dtypes(include=['object'])
sample_dfo.shape
#get levels for all variables
vn = pd.DataFrame(sample_dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#         VarName  LevelsCount
# 0     area_name           21
# 1   crm_cd_desc           76
# 2      vict_sex            3
# 3  vict_descent           15
# 4   premis_desc          200
# 5   weapon_desc           63
# 6        status            6
# 7   status_desc            6
# 8      location        12522

# %%
len(sample_df[sample_df.crm_cd_desc == 'OTHER MISCELLANEOUS CRIME'])
# Out:
# 232

# %% [markdown]
# ## Create dummy features for categorical variables

# %% [markdown]
# ### Binary encoding

# %% [markdown]
# #### Encoding the categorical variables using category_encoders

# %%
import category_encoders as ce

encoder = ce.BinaryEncoder(cols=['area_name', 'vict_sex', 'vict_descent', 'premis_desc',
                                 'weapon_desc', 'status_desc', 'location'])
sample_df_binary = encoder.fit_transform(sample_df)

sample_df_binary.head()
# Out:
#      index      dr_no  area  area_name_0  area_name_1  area_name_2  \
# 0  1110886  151200099    12            0            0            0
# 1   349876  111212546    12            0            0            0
# 2   104180  101217118    12            0            0            0
# 3  2052286  190109104     1            0            0            0
# 4  1594714  170105069     1            0            0            0
#
#    area_name_3  area_name_4  area_name_5  crm_cd  ... location_13  \
# 0            0            0            1     648  ...           0
# 1            0            0            1     648  ...           1
# 2            0            0            1     648  ...           1
# 3            0            1            0     648  ...           0
# 4            0            1            0     648  ...           0
#
#    location_14      lat       lon  day_crime_occ  no_rptd_occ  Hour  Minutes  \
# 0            1  33.9773 -118.2892              4            1     1       17
# 1            0  33.9678 -118.2871              6            0     6        0
# 2            1  33.9647 -118.2608              1            3    23        0
# 3            0  34.0423 -118.2631              4            0     6       30
# 4            1  34.0515 -118.2424              3            0     9       30
#
#    month_crime_occ  year_crime_occ
# 0                2            2015
# 1                5            2011
# 2                6            2010
# 3                3            2019
# 4                1            2017
#
# [5 rows x 66 columns]

# %%
#deleting the unnecessary features
sample_df_binary.drop(['index','dr_no','area','status'],axis=1,inplace = True)

# %% [markdown]
# #### Idendifying correlated variables using pearson correlation

# %%
# Step 1. Call the variable corr_matrix
corr_matrix= sample_df_binary.corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Let's see those features! 
print('Features selected to drop include:',to_drop)
print('Reduced dataframe size: ',sample_df_binary.drop(sample_df_binary[to_drop], axis=1).shape)
# Out:
# Features selected to drop include: ['lon']
# Reduced dataframe size:  (19918, 61)

# %% [markdown]
# #### Split the data into test and train

# %%
sample_df_binary.select_dtypes(include=['object']).columns
# Out:
# Index(['crm_cd_desc'], dtype='object')

# %%
# Split the data 
from sklearn.model_selection import train_test_split
X = sample_df_binary.drop(['crm_cd_desc'],axis= 1)
y = sample_df_binary.crm_cd_desc

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=123,stratify = y)

# %% [markdown]
# #### Scale the data to prepare for model creation

# %%
#Scale the data
from sklearn.preprocessing import StandardScaler
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
sample_df_binary.to_csv("/Users/HOME/Desktop/LosAngelesCrime/data/preprocess_output.csv")
